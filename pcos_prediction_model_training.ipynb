# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv('/content/pcos_prediction_dataset.csv')

# %%
df.sample(3)
# Out:
#           Country  Age         BMI Menstrual Regularity Hirsutism  \
# 63373  Uzbekistan   25  Overweight              Regular        No
# 66258     Ecuador   34      Normal              Regular       Yes
# 97618  Bangladesh   27  Overweight              Regular       Yes
#
#       Acne Severity Family History of PCOS Insulin Resistance  \
# 63373          Mild                     No                 No
# 66258           NaN                    Yes                Yes
# 97618           NaN                     No                 No
#
#        Lifestyle Score Stress Levels Urban/Rural Socioeconomic Status  \
# 63373                4          High       Rural               Middle
# 66258                3        Medium       Urban               Middle
# 97618                8        Medium       Urban                  Low
#
#       Awareness of PCOS Fertility Concerns  Undiagnosed PCOS Likelihood  \
# 63373                No                 No                     0.108533
# 66258               Yes                 No                     0.210803
# 97618               Yes                 No                     0.104777
#
#        Ethnicity Diagnosis
# 63373  Caucasian        No
# 66258    African        No
# 97618      Asian        No

# %%
df.isnull().sum()
# Out:
# Country                            0
# Age                                0
# BMI                                0
# Menstrual Regularity               0
# Hirsutism                          0
# Acne Severity                  60085
# Family History of PCOS             0
# Insulin Resistance                 0
# Lifestyle Score                    0
# Stress Levels                      0
# Urban/Rural                        0
# Socioeconomic Status               0
# Awareness of PCOS                  0
# Fertility Concerns                 0
# Undiagnosed PCOS Likelihood        0
# Ethnicity                          0
# Diagnosis                          0
# dtype: int64

# %%
df['Acne Severity'] = df['Acne Severity'].fillna("Unknown")

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Country                      120000 non-null  object
#  1   Age                          120000 non-null  int64
#  2   BMI                          120000 non-null  object
#  3   Menstrual Regularity         120000 non-null  object
#  4   Hirsutism                    120000 non-null  object
#  5   Acne Severity                120000 non-null  object
#  6   Family History of PCOS       120000 non-null  object
#  7   Insulin Resistance           120000 non-null  object
#  8   Lifestyle Score              120000 non-null  int64
#  9   Stress Levels                120000 non-null  object
#  10  Urban/Rural                  120000 non-null  object
#  11  Socioeconomic Status         120000 non-null  object
#  12  Awareness of PCOS            120000 non-null  object
#  13  Fertility Concerns           120000 non-null  object
#  14  Undiagnosed PCOS Likelihood  120000 non-null  float64
#  15  Ethnicity                    120000 non-null  object
#  16  Diagnosis                    120000 non-null  object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 15.6+ MB

# %%
df = df.drop(columns=['Awareness of PCOS', 'Fertility Concerns','Country','Lifestyle Score','Ethnicity','Undiagnosed PCOS Likelihood'])

# %%
df.sample(5)
# Out:
#        Age         BMI Menstrual Regularity Hirsutism Acne Severity  \
# 27355   17  Overweight              Regular        No          Mild
# 16171   32      Normal              Regular        No          Mild
# 65960   37      Normal            Irregular        No       Unknown
# 53041   16       Obese              Regular        No       Unknown
# 30937   24       Obese            Irregular       Yes      Moderate
#
#       Family History of PCOS Insulin Resistance Stress Levels Urban/Rural  \
# 27355                    Yes                 No        Medium       Urban
# 16171                     No                 No        Medium       Urban
# 65960                    Yes                 No           Low       Urban
# 53041                     No                 No           Low       Urban
# 30937                    Yes                 No        Medium       Urban
#
#       Socioeconomic Status Diagnosis
# 27355               Middle        No
# 16171                  Low        No
# 65960                 High        No
# 53041               Middle        No
# 30937               Middle        No

# %%
# Selecting features and target
X = df[['Age', 'BMI', 'Menstrual Regularity', 'Hirsutism', 'Acne Severity', 'Family History of PCOS', 'Insulin Resistance', 'Stress Levels', 'Urban/Rural', 'Socioeconomic Status' ]]
y= df[['Diagnosis']]

# %%
X
# Out:
#         Age          BMI Menstrual Regularity Hirsutism Acne Severity  \
# 0        26   Overweight              Regular       Yes        Severe
# 1        16  Underweight              Regular       Yes       Unknown
# 2        41       Normal              Regular        No      Moderate
# 3        27       Normal            Irregular        No          Mild
# 4        26   Overweight            Irregular       Yes       Unknown
# ...     ...          ...                  ...       ...           ...
# 119995   28       Normal              Regular        No      Moderate
# 119996   35   Overweight              Regular        No       Unknown
# 119997   16       Normal              Regular        No      Moderate
# 119998   15        Obese              Regular       Yes       Unknown
# 119999   17        Obese            Irregular       Yes       Unknown
#
#        Family History of PCOS Insulin Resistance Stress Levels Urban/Rural  \
# 0                         Yes                Yes           Low       Rural
# 1                          No                Yes          High       Rural
# 2                          No                 No        Medium       Urban
# 3                          No                 No           Low       Urban
# 4                          No                 No        Medium       Urban
# ...                       ...                ...           ...         ...
# 119995                    Yes                 No           Low       Urban
# 119996                     No                 No           Low       Rural
# 119997                     No                 No        Medium       Rural
# 119998                    Yes                Yes        Medium       Rural
# 119999                     No                 No        Medium       Rural
#
#        Socioeconomic Status
# 0                      High
# 1                    Middle
# 2                    Middle
# 3                      High
# 4                    Middle
# ...                     ...
# 119995               Middle
# 119996                 High
# 119997                  Low
# 119998                 High
# 119999                  Low
#
# [120000 rows x 10 columns]

# %%
# define categorical and numerical features
categorical_features = ['BMI','Menstrual Regularity', 'Hirsutism', 'Acne Severity', 'Family History of PCOS', 'Insulin Resistance', 'Stress Levels', 'Urban/Rural', 'Socioeconomic Status']
numercial_features = ['Age']

# %%
# column transformer for OneHotEncoding
preprocessor = ColumnTransformer(transformers=[("cat",OneHotEncoder(),categorical_features),
                                                ("num","passthrough",numercial_features)])

# %%
# Creating a pipeline with preprocessor and random forest classifier
pipeline = Pipeline(steps=[("preprocessor",preprocessor),
                           ("classifier", RandomForestClassifier(n_estimators=300, max_depth=10,min_samples_split=5,class_weight='balanced', random_state=42))])

# %%
# Split data
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=1)
pipeline.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   ['BMI',
#                                                    'Menstrual Regularity',
#                                                    'Hirsutism', 'Acne Severity',
#                                                    'Family History of PCOS',
#                                                    'Insulin Resistance',
#                                                    'Stress Levels',
#                                                    'Urban/Rural',
#                                                    'Socioeconomic Status']),
#                                                  ('num', 'passthrough',
#                                                   ['Age'])])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', max_depth=10,
#                                         min_samples_split=5, n_estimators=300,
#                                         random_state=42))])

# %%
# predict and evaluate
y_pred = pipeline.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6731666666666667

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.90      0.72      0.80     21570
#          Yes       0.10      0.27      0.14      2430
#
#     accuracy                           0.67     24000
#    macro avg       0.50      0.50      0.47     24000
# weighted avg       0.82      0.67      0.73     24000

# %%
import pickle

pickle_model_path = 'model.pkl'
with open(pickle_model_path, 'wb') as f:
  pickle.dump(pipeline,f)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1
